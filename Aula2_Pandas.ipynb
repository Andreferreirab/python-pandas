# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel('Aracaju.xlsx')
df2 = pd.read_excel('Fortaleza.xlsx')
df3 = pd.read_excel('Natal.xlsx')
df4 = pd.read_excel('Recife.xlsx')
df5 = pd.read_excel('Salvador.xlsx')

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Alteração do tipo de dados
df['LojaID'] = df['LojaID'].astype('object')
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
# Pega uma amostragem do Dataframe
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde
# 101    Recife 2019-01-01  172.55    983     7
# 50     Recife 2019-01-01    7.24    983     4
# 88     Recife 2019-01-01  180.24    980     6
# 40   Salvador 2019-02-13  161.87   1036     3
# 192     Natal 2019-01-02  166.51   1036     1

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df['Receita'] = df['Qtde']*df['Vendas']

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df.groupby(df['Data'].dt.year)['Receita'].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df['Ano_Venda'] = df['Data'].dt.year

# %%
df
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda
# 0     Aracaju 2018-01-01  142.00   1520     1   142.00       2018
# 1     Aracaju 2018-01-01   14.21   1522     6    85.26       2018
# 2     Aracaju 2018-01-01   71.55   1520     1    71.55       2018
# 3     Aracaju 2018-01-01    3.01   1521     7    21.07       2018
# 4     Aracaju 2018-01-01   24.51   1522     8   196.08       2018
# ..        ...        ...     ...    ...   ...      ...        ...
# 235  Salvador 2019-01-03   41.84   1034     1    41.84       2019
# 236  Salvador 2019-01-03  126.29   1035     3   378.87       2019
# 237  Salvador 2019-01-03   38.06   1036     3   114.18       2019
# 238  Salvador 2019-01-03  139.64   1035     1   139.64       2019
# 239  Salvador 2019-01-03  161.41   1037     3   484.23       2019
#
# [894 rows x 7 columns]

# %%
df['mes_venda'], df['dia_venda'] = (df['Data'].dt.month, df['Data'].dt.day)
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Ano_Venda  mes_venda  dia_venda
# 0  Aracaju 2018-01-01  142.00   1520     1       2018          1          1
# 1  Aracaju 2018-01-01   14.21   1522     6       2018          1          1
# 2  Aracaju 2018-01-01   71.55   1520     1       2018          1          1
# 3  Aracaju 2018-01-01    3.01   1521     7       2018          1          1
# 4  Aracaju 2018-01-01   24.51   1522     8       2018          1          1

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Ano_Venda  mes_venda  dia_venda
# 115    Recife 2019-03-02   12.23    981     3       2019          3          2
# 92     Recife 2019-01-01  163.02    981     4       2019          1          1
# 93     Recife 2019-01-01   17.45    980     6       2019          1          1
# 29     Recife 2019-01-01   10.18    980     8       2019          1          1
# 49   Salvador 2019-01-01   37.88   1034     2       2019          1          1

# %%
df['Data'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df['diferenca_dias'] = df['Data'] - df['Data'].min()

# %%
df.sample(5)
# Out:
#       Cidade       Data  Vendas  ... mes_venda  dia_venda  diferenca_dias
# 163    Natal 2019-01-02   17.66  ...         1          2        366 days
# 22     Natal 2018-06-21  621.00  ...         6         21        171 days
# 129    Natal 2019-01-02  125.66  ...         1          2        366 days
# 82   Aracaju 2018-01-01  150.48  ...         1          1          0 days
# 190    Natal 2019-01-02   78.78  ...         1          2        366 days
#
# [5 rows x 9 columns]

# %%
df['trimestre_venda'] = df['Data'].dt.quarter

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  ... dia_venda  diferenca_dias  trimestre_venda
# 226  Salvador 2019-01-02   38.32  ...         2        366 days                1
# 0       Natal 2018-08-27  606.00  ...        27        238 days                3
# 21    Aracaju 2018-01-01   37.36  ...         1          0 days                1
# 48    Aracaju 2018-01-01   35.90  ...         1          0 days                1
# 54     Recife 2019-01-01   23.43  ...         1        365 days                1
#
# [5 rows x 10 columns]

# %%
vendas_marco_19 = df.loc[(df['Data'].dt.year == 2019) & (df['Data'].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas  ... dia_venda  diferenca_dias  trimestre_venda
# 131   Salvador 2019-03-02   63.48  ...         2        425 days                1
# 138  Fortaleza 2019-03-02  150.38  ...         2        425 days                1
# 4        Natal 2019-03-09  699.00  ...         9        432 days                1
# 120  Fortaleza 2019-03-02  184.90  ...         2        425 days                1
# 126   Salvador 2019-03-02   41.69  ...         2        425 days                1
# 114     Recife 2019-03-02   16.82  ...         2        425 days                1
# 115   Salvador 2019-03-02  202.33  ...         2        425 days                1
# 114  Fortaleza 2019-03-02   16.82  ...         2        425 days                1
# 129   Salvador 2019-03-02  125.66  ...         2        425 days                1
# 8        Natal 2019-03-27  667.00  ...        27        450 days                1
# 115     Recife 2019-03-02   12.23  ...         2        425 days                1
# 45       Natal 2019-03-11  431.00  ...        11        434 days                1
# 139  Fortaleza 2019-03-02  141.16  ...         2        425 days                1
# 2        Natal 2019-03-11  308.00  ...        11        434 days                1
# 109     Recife 2019-03-02   18.90  ...         2        425 days                1
# 112   Salvador 2019-03-02   43.00  ...         2        425 days                1
# 121     Recife 2019-03-02   41.55  ...         2        425 days                1
# 125  Fortaleza 2019-03-02   37.60  ...         2        425 days                1
# 112     Recife 2019-03-02  133.59  ...         2        425 days                1
# 134   Salvador 2019-03-02  125.90  ...         2        425 days                1
#
# [20 rows x 10 columns]

# %% [markdown]
# ## Visualização de Dados

# %%
df['LojaID'].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1002     30
# 1005     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df['LojaID'].value_counts(ascending=False).plot.bar()

# %%
df['LojaID'].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df['Data'].dt.year)['Receita'].sum().plot.pie();

# %%
# Total de vendas por cidade
df['Cidade'].value_counts()
# Out:
# Natal        240
# Salvador     240
# Recife       142
# Fortaleza    142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
df['Cidade'].value_counts().plot.bar(title='Total de vendas por Cidade');
plt.xlabel('Cidade')
plt.ylabel('Total Vendas')
# Out:
# Text(0, 0.5, 'Total Vendas')

# %%
plt.style.use('ggplot')

# %%
df['Cidade'].value_counts().plot.bar(title='Total de vendas por Cidade', color='red');
plt.xlabel('Cidade')
plt.ylabel('Total Vendas');

# %%
df.groupby(df['mes_venda'])['Qtde'].sum().plot(title = "Total de Produtos Vendidos por mês");
plt.xlabel('Mês')
plt.ylabel('Total Produtos Vendidos')
plt.legend();

# %%
df.groupby(df['mes_venda'])['Qtde'].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum()
# Out:
# mes_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum().plot(marker = 'v', title = "Total de Produtos Vendidos por mês - 2019");
plt.xlabel('Mês')
plt.ylabel('Total de Produtos Vendidos');
plt.legend();

# %%
plt.hist(df['Qtde'], color='lightpink')
# Out:
# (array([191., 193., 221.,  85.,  54.,  61.,  38.,  31.,  14.,   6.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x=df_2019['dia_venda'], y = df_2019['Receita']);

# %%
# Salvando em PNG
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum().plot(marker='v')
plt.title('Quantidade de produtos vendidos x mês')
plt.xlabel('Mês')
plt.ylabel('Total Produtos Vendidos');
plt.legend();
plt.savefig('gráfico QTDE x MES.png')
